# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
x = np.linspace(0, 7, 101)
k = 1.9
plt.plot(x, np.cos(x))
plt.plot(x, np.cos(k*x))
plt.legend(labels=['y=cos(x)', f'y=cos({k}x)']);
